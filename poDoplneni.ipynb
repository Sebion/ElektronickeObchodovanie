# %%
import pandas as pd
# hlavna = pd.read_csv('data_auctionHIsim2024/hlavna_doplnena.csv')
filtered_hlavna = pd.read_csv('filtered_hlavna_positive.csv')
filtered_hlavna
# Out:
#           UniqueID  Org  AucID               AucZac               AucKon  \
# 0      100-45-1364   45   1364  2017-10-13 13:30:00  2017-10-23 13:33:00
# 1      100-45-1365   45   1365  2017-10-06 12:00:00  2017-10-27 12:00:00
# 2      100-45-1369   45   1369  2017-10-12 08:30:00  2017-10-27 08:30:00
# 3      100-45-1378   45   1378  2017-10-17 12:30:00  2017-10-31 11:30:00
# 4      100-45-1379   45   1379  2017-10-23 10:00:00  2017-10-31 09:40:00
# ...            ...  ...    ...                  ...                  ...
# 1615  1105-60-3188   60   3188  2020-01-29 10:00:00  2020-01-29 13:00:00
# 1616  1105-60-3189   60   3189  2020-01-30 10:30:00  2020-01-30 13:30:00
# 1617  1105-60-3190   60   3190  2020-01-30 10:30:00  2020-01-30 13:30:00
# 1618  1105-60-3191   60   3191  2020-02-06 07:30:00  2020-02-10 02:30:00
# 1619  1105-60-3192   60   3192  2020-02-03 14:30:00  2020-02-18 13:00:00
#
#             AucNazov1                      AucVal  Porovnávacia cena  \
# ...

# %%
hlavna = filtered_hlavna

# %%
negative_vitazna_ponuka = hlavna.loc[hlavna['VitaznaPonuka'] < 0]
negative_vitazna_ponuka
# Out:
# Empty DataFrame
# Columns: [UniqueID, Org, AucID, AucZac, AucKon, AucNazov1, AucVal, Porovnávacia cena, VitaznaPonuka, Mena, PocetPozvanok, PocetPrihlasenychUcast, PocetAktivnychUcast, Vitaz, AucTypUpresnenie, Kateg, Subkateg, PocetItems, PocetZmienPonuk, PocetPredlzeni, Stat, MinKrokZnizPercenta, PocKolERMMA, PocKolZadavac, PocKolNIPPON, PocKolHOLLAND, UsporaPorov, UsporaVstup, UsporaAukc, KoefVarPonukCelk, KoefVarPonukERMNIP]
# Index: []
#
# [0 rows x 31 columns]

# %%
hlavna.dtypes
# Out:
# UniqueID                   object
# Org                         int64
# AucID                       int64
# AucZac                     object
# AucKon                     object
# AucNazov1                  object
# AucVal                     object
# Porovnávacia cena         float64
# VitaznaPonuka             float64
# Mena                       object
# PocetPozvanok               int64
# PocetPrihlasenychUcast    float64
# PocetAktivnychUcast       float64
# Vitaz                       int64
# AucTypUpresnenie           object
# Kateg                      object
# Subkateg                   object
# PocetItems                  int64
# PocetZmienPonuk           float64
# PocetPredlzeni              int64
# Stat                       object
# MinKrokZnizPercenta       float64
# PocKolERMMA                object
# PocKolZadavac              object
# PocKolNIPPON               object
# PocKolHOLLAND              object
# UsporaPorov                object
# ...

# %%
hlavna_sorted = hlavna.sort_values('AucZac')
hlavna_sorted.head(50)
# Out:
#          UniqueID  Org  AucID               AucZac               AucKon  \
# 1     100-45-1365   45   1365  2017-10-06 12:00:00  2017-10-27 12:00:00
# 2     100-45-1369   45   1369  2017-10-12 08:30:00  2017-10-27 08:30:00
# 0     100-45-1364   45   1364  2017-10-13 13:30:00  2017-10-23 13:33:00
# 780  1104-50-1874   50   1874  2017-10-17 12:00:00  2017-10-19 09:00:00
# 3     100-45-1378   45   1378  2017-10-17 12:30:00  2017-10-31 11:30:00
# 7     100-45-1383   45   1383  2017-10-18 13:30:00  2017-10-23 09:54:00
# 8     100-45-1385   45   1385  2017-10-20 07:36:00  2017-11-03 06:36:00
# 623    1072-6-682    6    682  2017-10-20 12:00:00  2017-10-24 11:24:00
# 4     100-45-1379   45   1379  2017-10-23 10:00:00  2017-10-31 09:40:00
# 5     100-45-1380   45   1380  2017-10-23 10:00:00  2017-10-31 11:46:00
# 6     100-45-1382   45   1382  2017-10-23 10:00:00  2017-10-31 13:41:00
# 9     100-45-1386   45   1386  2017-10-24 09:30:00  2017-10-30 12:00:00
# ...

# %%
columns_to_drop = ['PocetPrihlasenychUcast', 'PocKolERMMA', 'PocKolZadavac', 'PocKolNIPPON', 'PocKolHOLLAND', 'UsporaPorov', 'UsporaVstup', 'UsporaAukc', 'KoefVarPonukCelk', 'KoefVarPonukERMNIP']
hlavna_sorted = hlavna_sorted.drop(columns_to_drop, axis=1)

# %%
hlavna_sorted.head()
# Out:
#          UniqueID  Org  AucID               AucZac               AucKon  \
# 1     100-45-1365   45   1365  2017-10-06 12:00:00  2017-10-27 12:00:00
# 2     100-45-1369   45   1369  2017-10-12 08:30:00  2017-10-27 08:30:00
# 0     100-45-1364   45   1364  2017-10-13 13:30:00  2017-10-23 13:33:00
# 780  1104-50-1874   50   1874  2017-10-17 12:00:00  2017-10-19 09:00:00
# 3     100-45-1378   45   1378  2017-10-17 12:30:00  2017-10-31 11:30:00
#
#            AucNazov1                      AucVal  Porovnávacia cena  \
# 1    Cenová poptávka  Multikriteriální hodnocení               0.00
# 2    Cenová poptávka  Multikriteriální hodnocení               0.00
# 0    Ocelové pásky v          Jednotlivé položky           24167.04
# 780  Fasáda kotelny           Jednotlivé položky         1818000.00
# 3    Cenová poptávka  Multikriteriální hodnocení               0.00
#
#      VitaznaPonuka Mena  ...  PocetAktivnychUcast  Vitaz  AucTypUpresnenie  \
# ...

# %%
grouped = hlavna_sorted.groupby('Org')
sorted_grouped = grouped.apply(lambda x: x.sort_values(['Org', 'AucZac']))
sorted_grouped.head(500)
# Out:
# /var/folders/cj/vh3ymv8n1tsf0kp09s2k65l80000gq/T/ipykernel_47237/485560258.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sorted_grouped = grouped.apply(lambda x: x.sort_values(['Org', 'AucZac']))
#               UniqueID  Org  AucID               AucZac               AucKon  \
# Org
# 6   623     1072-6-682    6    682  2017-10-20 12:00:00  2017-10-24 11:24:00
#     624     1072-6-686    6    686  2017-10-24 12:03:00  2017-10-25 10:08:00
#     625     1072-6-689    6    689  2017-11-10 10:00:00  2017-11-14 10:33:00
#     627     1072-6-691    6    691  2017-11-13 10:30:00  2017-11-14 10:20:00
#     626     1072-6-690    6    690  2017-11-13 11:00:00  2017-11-16 10:15:00
# ...

# %%
num_rows_per_group = grouped.size()
print(num_rows_per_group)
# Out:
# Org
# 6      150
# 24      17
# 45      72
# 50      87
# 60     753
# 77      74
# 78       9
# 79       8
# 81      21
# 82      41
# 83       4
# 84      46
# 85       9
# 86      11
# 87      13
# 88       9
# 89      12
# 90       8
# 91      25
# 92       6
# 93      17
# 94       6
# 95      25
# 96      23
# 97      10
# 98       5
# 99      13
# 100     20
# 101      8
# 102     58
# 103     17
# 143     20
# 146     14
# 168      1
# 181      8
# dtype: int64

# %%
org_with_50_rows = num_rows_per_group[num_rows_per_group > 30]
print(org_with_50_rows)
# Out:
# Org
# 6      150
# 45      72
# 50      87
# 60     753
# 77      74
# 82      41
# 84      46
# 102     58
# dtype: int64

# %%
org_121 = hlavna_sorted[hlavna_sorted['Org'] == 50]
org_121
# Out:
#          UniqueID  Org  AucID               AucZac               AucKon  \
# 780  1104-50-1874   50   1874  2017-10-17 12:00:00  2017-10-19 09:00:00
# 781  1104-50-1876   50   1876  2017-11-21 16:00:00  2017-11-22 14:00:00
# 782  1104-50-1877   50   1877  2017-11-22 13:00:00  2017-11-27 09:50:00
# 783  1104-50-1878   50   1878  2017-12-06 09:00:00  2017-12-06 14:00:00
# 784  1104-50-1879   50   1879  2017-12-15 11:00:00  2017-12-20 11:00:00
# ..            ...  ...    ...                  ...                  ...
# 862  1104-50-1974   50   1974  2020-04-23 10:00:00  2020-04-23 13:00:00
# 863  1104-50-1977   50   1977  2020-05-25 14:00:00  2020-05-26 10:00:00
# 864  1104-50-1978   50   1978  2020-06-02 15:00:00  2020-06-03 10:15:00
# 865  1104-50-1979   50   1979  2020-06-04 07:30:00  2020-06-04 12:00:00
# 866  1104-50-1980   50   1980  2020-06-12 08:00:00  2020-06-16 10:17:00
#
#            AucNazov1                      AucVal  Porovnávacia cena  \
# ...

# %%
grouped_by_vitaz = org_121.groupby('Vitaz')
num_rows_per_vitaz = grouped_by_vitaz.size()
num_rows_per_vitaz
# Out:
# Vitaz
# 5133     2
# 6078    10
# 7836     2
# 7837     1
# 7849     1
# 7850     1
# 7860     2
# 7861    34
# 7862     6
# 7871     4
# 7878     1
# 7934     3
# 7960     2
# 7970     1
# 7972     3
# 7973     1
# 7977     1
# 7981     2
# 7982     1
# 7983     2
# 7990     1
# 7992     2
# 7996     1
# 7999     1
# 8003     1
# 8004     1
# dtype: int64

# %%
vitaz_6542 = org_121[org_121['Vitaz'] == 6078]
vitaz_6542
# Out:
#          UniqueID  Org  AucID               AucZac               AucKon  \
# 794  1104-50-1889   50   1889  2018-04-17 11:00:00  2018-04-18 10:52:00
# 802  1104-50-1898   50   1898  2018-06-27 13:00:00  2018-07-02 10:30:00
# 812  1104-50-1915   50   1915  2018-11-14 12:30:00  2018-11-14 15:48:00
# 813  1104-50-1916   50   1916  2018-11-15 09:30:00  2018-11-16 13:02:00
# 815  1104-50-1918   50   1918  2018-11-16 13:15:00  2018-11-16 13:47:00
# 816  1104-50-1920   50   1920  2018-11-20 13:00:00  2018-11-22 10:19:00
# 817  1104-50-1921   50   1921  2018-11-20 13:30:00  2018-11-22 13:21:00
# 818  1104-50-1923   50   1923  2018-12-06 12:00:00  2018-12-07 10:07:00
# 845  1104-50-1956   50   1956  2019-11-27 12:00:00  2019-11-27 12:44:00
# 852  1104-50-1963   50   1963  2020-01-17 11:30:00  2020-01-20 12:13:00
#
#            AucNazov1                      AucVal  Porovnávacia cena  \
# 794  Tender CoCrMo a   Celková nabídka účastníka            78470.0
# ...

# %%
# Group by 'Org' and 'Vitaz' and sort by 'AucZac'
hlavna_sorted = hlavna_sorted.sort_values(['Org', 'Vitaz', 'AucZac'])
# grouped = hlavna_sorted.groupby(['Org', 'Vitaz'])
grouped = hlavna_sorted.groupby(['Org', 'Subkateg'])


# Calculate cumulative count
hlavna_sorted['HistoryDealsInCategory'] = grouped.cumcount() + 1

# %%
# Group by 'Org' and 'Vitaz' and sort by 'AucZac'
hlavna_sorted = hlavna_sorted.sort_values(['Org', 'Vitaz', 'AucZac'])
grouped = hlavna_sorted.groupby(['Org', 'Vitaz'])
# grouped = hlavna_sorted.groupby(['Org', 'Subkateg'])

# Calculate cumulative count
hlavna_sorted['HistoryDealsWithVitaz'] = grouped.cumcount() + 1

# %%
# Group by 'Org' and 'Vitaz' and sort by 'AucZac'
hlavna_sorted = hlavna_sorted.sort_values(['Org', 'Vitaz', 'AucZac'])
# grouped = hlavna_sorted.groupby(['Org', 'Vitaz'])
grouped = hlavna_sorted.groupby(['Org', 'Subkateg'])


# Calculate cumulative sum
hlavna_sorted['MoneySpentSoFarInCategory'] = grouped['VitaznaPonuka'].cumsum()

# %%
# Group by 'Org' and 'Vitaz' and sort by 'AucZac'
hlavna_sorted = hlavna_sorted.sort_values(['Org', 'Vitaz', 'AucZac'])
grouped = hlavna_sorted.groupby(['Org', 'Vitaz'])
# grouped = hlavna_sorted.groupby(['Org', 'Subkateg'])


# Calculate cumulative sum
hlavna_sorted['MoneySpentSoFarWithVitaz'] = grouped['VitaznaPonuka'].cumsum()

# %%
hlavna_sorted = hlavna_sorted.sort_values(['Org', 'Subkateg', 'Vitaz', 'AucZac'])

hlavna_sorted
# Out:
#           UniqueID  Org  AucID               AucZac               AucKon  \
# 636     1072-6-713    6    713  2018-01-29 11:00:00  2018-01-30 09:50:00
# 660     1072-6-776    6    776  2018-07-18 06:30:00  2018-07-23 10:46:00
# 661     1072-6-783    6    783  2018-08-06 08:30:00  2018-08-07 09:40:00
# 678     1072-6-829    6    829  2018-11-13 12:00:00  2018-11-14 11:55:00
# 706     1072-6-881    6    881  2019-04-01 13:30:00  2019-04-02 09:54:00
# ..             ...  ...    ...                  ...                  ...
# 594  1065-181-5897  181   5897  2019-07-01 13:00:00  2019-07-08 12:56:00
# 590  1065-181-5892  181   5892  2019-04-30 10:00:00  2019-04-30 13:28:00
# 592  1065-181-5895  181   5895  2019-05-14 10:07:00  2019-05-15 09:06:00
# 589  1065-181-5891  181   5891  2018-09-21 13:00:00  2018-09-24 10:08:00
# 593  1065-181-5896  181   5896  2019-05-16 10:00:00  2019-05-17 09:09:00
#
#            AucNazov1                     AucVal  Porovnávacia cena  \
# ...

# %%
#POZNAMKY:

#mozeme hned povedat podla poctu pozvanok ktora polozka je najrizikovejsia
#dopocitat agregovane ze kolko a ako casto nakupujem od dodavatela
#postupne pre vsetky riadky dopocitat kolko predtym minul
#groupby-lambda
#zoradit v case


#DOPOCitat len podla kategorii a len za organizaciu

#predelit a intenzita ze kolko od koho od akeho vitaza percenta

#intenzita ABC MATICA podiel obstaravania v danej kategorii
# ako lahko sa da vymenit dany dodavatel
# zobrazovat kto nabera dominanciu ktory dodavatel

#

# %%
hlavna_sorted.to_csv('filtered_hlavna_sorted_doplnena_final.csv', index=False)

# %%
hlavna_sorted.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 hlavna_sorted.head()
#
# NameError: name 'hlavna_sorted' is not defined
